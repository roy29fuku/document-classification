# %%
import nltk
import numpy as np
import re

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from named_entity_recognition.util import data_loader

# %%
BOS = '<BOS>'
EOS = '<EOS>'
UNK = '<UNK>'

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = data_loader.load_sentences()
# Out:
# hoge
# /Users/Ryota/Google_Drive_fuku/workspace/natural-language-processing
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-6ddc084d0f0c> in <module>()
# ----> 1 X_train, y_train, X_valid, y_valid, X_test, y_test = data_loader.load_sentences()
#
# ~/Google_Drive_fuku/workspace/natural-language-processing/named_entity_recognition/util/data_loader.py in load_sentences()
#      17     print('hoge')
#      18     print(os.getcwd())
# ---> 19     X_train, y_train = load_conll2003_sentences(TRAIN_FILE_PATH)
#      20     X_valid, y_valid = load_conll2003_sentences(VALID_FILE_PATH)
#      21     X_test, y_test = load_conll2003_sentences(TEST_FILE_PATH)
#
# ~/Google_Drive_fuku/workspace/natural-language-processing/named_entity_recognition/util/data_loader.py in load_conll2003_sentences(file_path)
#      40
#      41             if line:
# ...

# %%
def load_conll2003_sentences(file_path):
    """
    CoNLL-2003形式のデータを文章単位で読み込む
    :param file_path:
    :return:
    """
    sentences, labels = [], []
    sentence, label = [], []

    with open(file_path) as f:
        for line in f:
            line = line.rstrip()
            if line.startswith('-DOCSTART-'):
                continue

            if line:
                word, _, _, ner_label = line.split()
                sentence.append(word)
                label.append(ner_label)
            else:
                if not sentence:
                    continue
                sentences.append(sentence)
                labels.append(label)
                sentence, label = [], []

    return sentences, labels

# %%
TRAIN_FILE_PATH = 'named_entity_recognition/data/eng.train'
sentences, labels = load_conll2003_sentences(TRAIN_FILE_PATH)

# %%
sentences[:20]
# Out:
# [['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.'],
#  ['Peter', 'Blackburn'],
#  ['BRUSSELS', '1996-08-22'],
#  ['The',
#   'European',
#   'Commission',
#   'said',
#   'on',
#   'Thursday',
#   'it',
#   'disagreed',
#   'with',
#   'German',
#   'advice',
#   'to',
#   'consumers',
#   'to',
#   'shun',
#   'British',
#   'lamb',
#   'until',
#   'scientists',
#   'determine',
#   'whether',
#   'mad',
#   'cow',
#   'disease',
#   'can',
#   'be',
#   'transmitted',
#   'to',
#   'sheep',
#   '.'],
#  ['Germany',
#   "'s",
#   'representative',
#   'to',
#   'the',
#   'European',
#   'Union',
#   "'s",
#   'veterinary',
#   'committee',
#   'Werner',
#   'Zwingmann',
#   'said',
#   'on',
#   'Wednesday',
#   'consumers',
#   'should',
#   'buy',
#   'sheepmeat',
#   'from',
#   'countries',
#   'other',
#   'than',
#   'Britain',
#   'until',
#   'the',
#   'scientific',
#   'advice',
#   'was',
#   'clearer',
#   '.'],
#  ['"',
#   'We',
#   'do',
# ...

# %%
labels[1]
# Out:
# ['I-ORG', 'O', 'I-MISC', 'O', 'O', 'O', 'I-MISC', 'O', 'O']

# %%
len(labels)
# Out:
# 14041
